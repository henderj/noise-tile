# %%
import numpy as np
from PIL import Image
from perlin_noise import PerlinNoise
import matplotlib.pyplot as plt

# %%
import ipywidgets as widgets
from ipywidgets import interact

# %%
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# %%
# %matplotlib notebook

# %%
noise = PerlinNoise(octaves=7, seed=6)
xpix, ypix = 128, 128
frames = 16
grayscale = [[[noise([f/32, i/xpix, j/ypix]) for j in range(xpix)] for i in range(ypix)] for f in range(frames)]

# %%
#purple
from colour import Color
first = Color("#0f0417")
second = Color("#2d1455")
dist = 66
third = Color("#640f9c")
colors1 = list(first.range_to(second, dist))
colors2 = list(second.range_to(third, 100-dist))
colors = colors1 + colors2

# %%
#lava
from colour import Color
first = Color("#dd9f0d")
second = Color("#d9671a")
dist = 22
third = Color("#871818")
colors1 = list(first.range_to(second, dist))
colors2 = list(second.range_to(third, 100-dist))
colors = colors1 + colors2

# %%
data_np = np.array(grayscale)
temp = np.add(data_np, 0.5)
temp = np.multiply(temp, 100)
temp = np.floor(temp)
temp = np.clip(temp, 0, 99)
grad_indices = np.array(temp, dtype=np.int32)

# %%
flat = grad_indices.flatten()
flat_rgb = np.array([colors[i].rgb for i in flat]).flatten()
rgb_data = np.reshape(flat_rgb, (frames,xpix,ypix,3))

# %%
fig, ax = plt.subplots()


def get_frame(f):
    return rgb_data[f]


# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
ims = []
for i in range(len(rgb_data)):
    im = ax.imshow(get_frame(i), animated=True)
    if i == 0:
        ax.imshow(get_frame(i))  # show an initial one first
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=150, blit=True,
                                repeat_delay=0)

# To save the animation, use e.g.
#
# ani.save("movie.mp4")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
